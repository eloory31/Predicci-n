# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms as transforms
from skimage.util import montage
import os
import cv2 
import random
import matplotlib.pyplot as plt 
import torch.optim as optim
from PIL import Image
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, confusion_matrix
from torch.utils.tensorboard import SummaryWriter
import glob
import shutil
import numpy as np
from torchvision.models import vgg19_bn
import numpy as np
import seaborn as sns
import pandas as pd
from imutils import paths

random.seed(0)

log_dir = "~/logs"
writer = SummaryWriter(log_dir)
device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# rm -rf Images-processed
# mkdir -p Images-processed
# mkdir -p COVID-CT/Data-split/NonCOVID/
# mkdir -p COVID-CT/Data-split/COVID/

# %%
# dataset_path_drive = 'drive/MyDrive/COVID-CT/'
dataset_path_drive = 'drive/MyDrive/dataset_2/' 
dataset_path_covid = 'COVID-CT/Data-split/COVID/'
dataset_path_non_covid = 'COVID-CT/Data-split/NonCOVID/'

# %%
def create_dataset_by_type(path_file, dataset_path_drive, type_metadata, init_range, end_range, column, upper=False):
  csvPath = os.path.sep.join([dataset_path_drive, type_metadata])
  df = pd.read_csv(csvPath, usecols=[column,"FORMAT"], delimiter=';')
  dataset = df.iloc[init_range:end_range]

  file = open(path_file, 'w+')
  for (i, row) in dataset.iterrows():
    file.write('{}.{}\n'.format(str(row[column]).capitalize() if upper else str(row[column]), str(row["FORMAT"]).lower()))
  
  file.close()

# %%
train_ct_covid = "COVID-CT/Data-split/COVID/trainCT_COVID.txt"
val_ct_covid = "COVID-CT/Data-split/COVID/valCT_COVID.txt"
test_ct_covid = "COVID-CT/Data-split/COVID/testCT_COVID.txt"

train_ct_non_covid = "COVID-CT/Data-split/NonCOVID/trainCT_NonCOVID.txt"
val_ct_non_covid = "COVID-CT/Data-split/NonCOVID/valCT_NonCOVID.txt"
test_ct_non_covid = "COVID-CT/Data-split/NonCOVID/testCT_NonCOVID.txt"

# %%
create_dataset_by_type(train_ct_covid, dataset_path_drive, "COVID.metadata.csv", 0, 192, "NAME")
create_dataset_by_type(val_ct_covid, dataset_path_drive, "COVID.metadata.csv", 192, 252, "NAME")
create_dataset_by_type(test_ct_covid, dataset_path_drive, "COVID.metadata.csv", 252, 350, "NAME")

create_dataset_by_type(train_ct_non_covid, dataset_path_drive, "Normal.metadata.csv", 0, 234, "FILE_NAME", True)
create_dataset_by_type(val_ct_non_covid, dataset_path_drive, "Normal.metadata.csv", 234, 292, "FILE_NAME", True)
create_dataset_by_type(test_ct_non_covid, dataset_path_drive, "Normal.metadata.csv", 292, 397, "FILE_NAME", True)

# %%
covid_files_path = dataset_path_drive + 'covid/'
covid_files      = [os.path.join(covid_files_path, x) for x in os.listdir(covid_files_path)]
covid_images    =  [cv2.imread(x) for x in random.sample(covid_files, 5)]

plt.figure(figsize=(20,10))
columns = 5
for i, image in enumerate(covid_images):
    plt.subplot(len(covid_images) / columns + 1, columns, i + 1)
    plt.imshow(image)

# %%
def read_txt(txt_path):
    with open(txt_path) as f:
        lines = f.readlines()
    txt_data = [line.strip() for line in lines]
    return txt_data

# %%
class CovidCTDataset(Dataset):
    def __init__(self, root_dir, classes, covid_files, non_covid_files, transform=None):
        self.root_dir = root_dir
        self.classes = classes
        self.files_path = [non_covid_files, covid_files]
        self.image_list = []

        # read the files from data split text files
        covid_files = read_txt(covid_files)
        non_covid_files = read_txt(non_covid_files)

        # combine the positive and negative files into a cummulative files list
        for cls_index in range(len(self.classes)):
            
            class_files = [[os.path.join(self.root_dir, self.classes[cls_index], x), cls_index] \
                            for x in read_txt(self.files_path[cls_index])]
            self.image_list += class_files
                
        self.transform = transform

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        path = self.image_list[idx][0]
        
        # Read the image
        image = Image.open(path).convert('RGB')
        
        # Apply transforms
        if self.transform:
            image = self.transform(image)

        label = int(self.image_list[idx][1])

        data = {'img':   image,
                'label': label,
                'paths' : path}

        return data

# %%
normalize = transforms.Normalize(mean=[0,0,0], std=[1,1,1])
train_transformer = transforms.Compose([
    transforms.Resize(256),  
    transforms.RandomResizedCrop((224),scale=(0.5,1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    normalize
])

val_transformer = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    normalize
])

# %%
batchsize = 8

trainset = CovidCTDataset(root_dir='drive/MyDrive/dataset_2',
                          classes = ['normal', 'covid'],
                          covid_files=train_ct_covid,
                          non_covid_files=train_ct_non_covid,
                          transform=train_transformer)
valset = CovidCTDataset(root_dir='drive/MyDrive/dataset_2',
                          classes = ['normal', 'covid'],
                          covid_files=val_ct_covid,
                          non_covid_files =val_ct_non_covid,
                          transform=val_transformer)
testset = CovidCTDataset(root_dir='drive/MyDrive/dataset_2',
                          classes = ['normal', 'covid'],
                          covid_files=test_ct_covid,
                          non_covid_files=test_ct_non_covid,
                          transform= val_transformer)

train_loader = DataLoader(trainset, batch_size=batchsize, drop_last=False, shuffle=True)
val_loader = DataLoader(valset, batch_size=batchsize, drop_last=False, shuffle=False)
test_loader = DataLoader(testset, batch_size=batchsize, drop_last=False, shuffle=False)

# %%
def compute_metrics(model, test_loader, plot_roc_curve = False):
    
    model.eval()
    
    val_loss = 0
    val_correct = 0
    
    criterion = nn.CrossEntropyLoss()
    
    score_list   = torch.Tensor([]).to(device)
    pred_list    = torch.Tensor([]).to(device).long()
    target_list  = torch.Tensor([]).to(device).long()
    path_list    = []

    
    for iter_num, data in enumerate(test_loader):
        
        # Convert image data into single channel data
        image, target = data['img'].to(device), data['label'].to(device)
        paths = data['paths']
        path_list.extend(paths)
        
        # Compute the loss
        with torch.no_grad():
            output = model(image)
        
        # Log loss
        val_loss += criterion(output, target.long()).item()

        
        # Calculate the number of correctly classified examples
        pred = output.argmax(dim=1, keepdim=True)
        val_correct += pred.eq(target.long().view_as(pred)).sum().item()
        
        # Bookkeeping 
        score_list   = torch.cat([score_list, nn.Softmax(dim = 1)(output)[:,1].squeeze()])
        pred_list    = torch.cat([pred_list, pred.squeeze()])
        target_list  = torch.cat([target_list, target.squeeze()])
        
    
    classification_metrics = classification_report(target_list.tolist(), pred_list.tolist(),
                                                  target_names = ['CT_NonCOVID', 'CT_COVID'],
                                                  output_dict= True)
    
    
    # sensitivity is the recall of the positive class
    sensitivity = classification_metrics['CT_COVID']['recall']
    
    # specificity is the recall of the negative class 
    specificity = classification_metrics['CT_NonCOVID']['recall']
    
    # accuracy
    accuracy = classification_metrics['accuracy']
    
    # confusion matrix
    conf_matrix = confusion_matrix(target_list.tolist(), pred_list.tolist())
    
    # roc score
    roc_score = roc_auc_score(target_list.tolist(), score_list.tolist())
    
    # plot the roc curve
    if plot_roc_curve:
        fpr, tpr, _ = roc_curve(target_list.tolist(), score_list.tolist())
        plt.plot(fpr, tpr, label = "Area under ROC = {:.4f}".format(roc_score))
        plt.legend(loc = 'best')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.show()
        
    
    # put together values
    metrics_dict = {"Accuracy": accuracy,
                    "Sensitivity": sensitivity,
                    "Specificity": specificity,
                    "Roc_score"  : roc_score, 
                    "Confusion Matrix": conf_matrix,
                    "Validation Loss": val_loss / len(test_loader),
                    "score_list":  score_list.tolist(),
                    "pred_list": pred_list.tolist(),
                    "target_list": target_list.tolist(),
                    "paths": path_list}
    
    
    return metrics_dict

# %%
model = vgg19_bn(pretrained=True)
model.classifier[6] = nn.Linear(4096, 2)
model.to(device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (25): ReLU(inplace=True)
#     (26): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (27): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (35): ReLU(inplace=True)
#     (36): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (37): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (38): ReLU(inplace=True)
#     (39): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (44): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (45): ReLU(inplace=True)
#     (46): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (47): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (48): ReLU(inplace=True)
#     (49): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (50): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (51): ReLU(inplace=True)
#     (52): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
learning_rate = 0.01
optimizer     = optim.SGD(model.parameters(), lr = learning_rate, momentum=0.9)

# %%
from collections import deque

class EarlyStopping(object):
    def __init__(self, patience = 8):
        super(EarlyStopping, self).__init__()
        self.patience = patience
        self.previous_loss = int(1e8)
        self.previous_accuracy = 0
        self.init = False
        self.accuracy_decrease_iters = 0
        self.loss_increase_iters = 0
        self.best_running_accuracy = 0
        self.best_running_loss = int(1e7)
    
    def add_data(self, model, loss, accuracy):
        
        # compute moving average
        if not self.init:
            running_loss = loss
            running_accuracy = accuracy 
            self.init = True
        
        else:
            running_loss = 0.2 * loss + 0.8 * self.previous_loss
            running_accuracy = 0.2 * accuracy + 0.8 * self.previous_accuracy
        
        # check if running accuracy has improved beyond the best running accuracy recorded so far
        if running_accuracy < self.best_running_accuracy:
            self.accuracy_decrease_iters += 1
        else:
            self.best_running_accuracy = running_accuracy
            self.accuracy_decrease_iters = 0
        
        # check if the running loss has decreased from the best running loss recorded so far
        if running_loss > self.best_running_loss:
            self.loss_increase_iters += 1
        else:
            self.best_running_loss = running_loss
            self.loss_increase_iters = 0
        
        # log the current accuracy and loss
        self.previous_accuracy = running_accuracy
        self.previous_loss = running_loss        
        
    
    def stop(self):
        
        # compute thresholds
        accuracy_threshold = self.accuracy_decrease_iters > self.patience
        loss_threshold = self.loss_increase_iters > self.patience
        
        
        # return codes corresponding to exhuaustion of patience for either accuracy or loss 
        # or both of them
        if accuracy_threshold and loss_threshold:
            return 1
        
        if accuracy_threshold:
            return 2
        
        if loss_threshold:
            return 3
        
        
        return 0
    
    def reset(self):
        # reset
        self.accuracy_decrease_iters = 0
        self.loss_increase_iters = 0
    
early_stopper = EarlyStopping(patience = 5)

# %%
best_model = model
best_val_score = 0

criterion = nn.CrossEntropyLoss()

for epoch in range(60):

    model.train()    
    train_loss = 0
    train_correct = 0
    
    for iter_num, data in enumerate(train_loader):
        image, target = data['img'].to(device), data['label'].to(device)     

        # Compute the loss
        output = model(image)
        loss = criterion(output, target.long()) / 8
        
        # Log loss
        train_loss += loss.item()
        loss.backward()

        # Perform gradient udpate
        if iter_num % 8 == 0:
            optimizer.step()
            optimizer.zero_grad()
            

        # Calculate the number of correctly classified examples
        pred = output.argmax(dim=1, keepdim=True)
        train_correct += pred.eq(target.long().view_as(pred)).sum().item()
        
    
    # Compute and print the performance metrics
    metrics_dict = compute_metrics(model, val_loader)
    print('------------------ Epoch {} Iteration {}--------------------------------------'.format(epoch,
                                                                                                 iter_num))
    print("Accuracy \t {:.3f}".format(metrics_dict['Accuracy']))
    print("Sensitivity \t {:.3f}".format(metrics_dict['Sensitivity']))
    print("Specificity \t {:.3f}".format(metrics_dict['Specificity']))
    print("Area Under ROC \t {:.3f}".format(metrics_dict['Roc_score']))
    print("Val Loss \t {}".format(metrics_dict["Validation Loss"]))
    print("------------------------------------------------------------------------------")
    
    # Save the model with best validation accuracy
    if metrics_dict['Accuracy'] > best_val_score:
        torch.save(model, "best_model.pkl")
        best_val_score = metrics_dict['Accuracy']
    
    
    # print the metrics for training data for the epoch
    print('\nTraining Performance Epoch {}: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        epoch, train_loss/len(train_loader.dataset), train_correct, len(train_loader.dataset),
        100.0 * train_correct / len(train_loader.dataset)))
    
    # log the accuracy and losses in tensorboard
    writer.add_scalars( "Losses", {'Train loss': train_loss / len(train_loader), 'Validation_loss': metrics_dict["Validation Loss"]},
                                   epoch)
    writer.add_scalars( "Accuracies", {"Train Accuracy": 100.0 * train_correct / len(train_loader.dataset),
                                       "Valid Accuracy": 100.0 * metrics_dict["Accuracy"]}, epoch)

    # Add data to the EarlyStopper object
    early_stopper.add_data(model, metrics_dict['Validation Loss'], metrics_dict['Accuracy'])
    
    # If both accuracy and loss are not improving, stop the training
    if early_stopper.stop() == 1:
        break
    
    # if only loss is not improving, lower the learning rate
    if early_stopper.stop() == 3:
        for param_group in optimizer.param_groups:
            learning_rate *= 0.1
            param_group['lr'] = learning_rate
            print('Updating the learning rate to {}'.format(learning_rate))
            early_stopper.reset()
# Out:
# ------------------ Epoch 0 Iteration 53--------------------------------------
# Accuracy 	 0.890
# Sensitivity 	 0.783
# Specificity 	 1.000
# Area Under ROC 	 1.000
# Val Loss 	 0.25996029272985954
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 0: Average loss: 0.0081, Accuracy: 319/426 (75%)
#
# ------------------ Epoch 1 Iteration 53--------------------------------------
# Accuracy 	 0.898
# Sensitivity 	 0.800
# Specificity 	 1.000
# Area Under ROC 	 0.996
# Val Loss 	 0.24837682018987833
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 1: Average loss: 0.0051, Accuracy: 378/426 (89%)
#
# ------------------ Epoch 2 Iteration 53--------------------------------------
# Accuracy 	 0.941
# Sensitivity 	 0.883
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.12838080492801965
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 2: Average loss: 0.0035, Accuracy: 390/426 (92%)
#
# ------------------ Epoch 3 Iteration 53--------------------------------------
# Accuracy 	 0.966
# Sensitivity 	 0.933
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.09695330811664463
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 3: Average loss: 0.0034, Accuracy: 388/426 (91%)
#
# ------------------ Epoch 4 Iteration 53--------------------------------------
# Accuracy 	 0.949
# Sensitivity 	 0.900
# Specificity 	 1.000
# Area Under ROC 	 0.995
# Val Loss 	 0.13041395209729673
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 4: Average loss: 0.0022, Accuracy: 401/426 (94%)
#
# ------------------ Epoch 5 Iteration 53--------------------------------------
# Accuracy 	 0.941
# Sensitivity 	 0.883
# Specificity 	 1.000
# Area Under ROC 	 0.997
# Val Loss 	 0.14560373383574188
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 5: Average loss: 0.0017, Accuracy: 409/426 (96%)
#
# ------------------ Epoch 6 Iteration 53--------------------------------------
# Accuracy 	 0.915
# Sensitivity 	 0.833
# Specificity 	 1.000
# Area Under ROC 	 0.988
# Val Loss 	 0.23695204871085782
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 6: Average loss: 0.0018, Accuracy: 405/426 (95%)
#
# ------------------ Epoch 7 Iteration 53--------------------------------------
# Accuracy 	 0.958
# Sensitivity 	 0.917
# Specificity 	 1.000
# Area Under ROC 	 0.995
# Val Loss 	 0.13350210752881442
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 7: Average loss: 0.0022, Accuracy: 402/426 (94%)
#
# ------------------ Epoch 8 Iteration 53--------------------------------------
# Accuracy 	 0.949
# Sensitivity 	 0.917
# Specificity 	 0.983
# Area Under ROC 	 0.989
# Val Loss 	 0.1306505377870053
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 8: Average loss: 0.0012, Accuracy: 413/426 (97%)
#
# ------------------ Epoch 9 Iteration 53--------------------------------------
# Accuracy 	 0.958
# Sensitivity 	 0.917
# Specificity 	 1.000
# Area Under ROC 	 1.000
# Val Loss 	 0.07653695583188286
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 9: Average loss: 0.0016, Accuracy: 409/426 (96%)
#
# ------------------ Epoch 10 Iteration 53--------------------------------------
# Accuracy 	 0.941
# Sensitivity 	 0.883
# Specificity 	 1.000
# Area Under ROC 	 1.000
# Val Loss 	 0.19047285792670057
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 10: Average loss: 0.0016, Accuracy: 411/426 (96%)
#
# ------------------ Epoch 11 Iteration 53--------------------------------------
# Accuracy 	 0.898
# Sensitivity 	 0.800
# Specificity 	 1.000
# Area Under ROC 	 0.992
# Val Loss 	 0.24926517897595962
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 11: Average loss: 0.0022, Accuracy: 405/426 (95%)
#
# ------------------ Epoch 12 Iteration 53--------------------------------------
# Accuracy 	 0.932
# Sensitivity 	 0.867
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.1656783511629328
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 12: Average loss: 0.0020, Accuracy: 405/426 (95%)
#
# ------------------ Epoch 13 Iteration 53--------------------------------------
# Accuracy 	 0.992
# Sensitivity 	 0.983
# Specificity 	 1.000
# Area Under ROC 	 1.000
# Val Loss 	 0.06058450314521906
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 13: Average loss: 0.0012, Accuracy: 417/426 (98%)
#
# ------------------ Epoch 14 Iteration 53--------------------------------------
# Accuracy 	 0.898
# Sensitivity 	 0.800
# Specificity 	 1.000
# Area Under ROC 	 0.995
# Val Loss 	 0.33803005174753104
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 14: Average loss: 0.0015, Accuracy: 416/426 (98%)
#
# ------------------ Epoch 15 Iteration 53--------------------------------------
# Accuracy 	 0.992
# Sensitivity 	 0.983
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.03587357852957211
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 15: Average loss: 0.0008, Accuracy: 419/426 (98%)
#
# Updating the learning rate to 0.001
# ------------------ Epoch 16 Iteration 53--------------------------------------
# Accuracy 	 0.983
# Sensitivity 	 0.967
# Specificity 	 1.000
# Area Under ROC 	 0.998
# Val Loss 	 0.056280540133593605
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 16: Average loss: 0.0012, Accuracy: 415/426 (97%)
#
# ------------------ Epoch 17 Iteration 53--------------------------------------
# Accuracy 	 0.966
# Sensitivity 	 0.933
# Specificity 	 1.000
# Area Under ROC 	 0.997
# Val Loss 	 0.08440008739222928
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 17: Average loss: 0.0006, Accuracy: 421/426 (99%)
#
# ------------------ Epoch 18 Iteration 53--------------------------------------
# Accuracy 	 0.941
# Sensitivity 	 0.883
# Specificity 	 1.000
# Area Under ROC 	 0.997
# Val Loss 	 0.13884098820514434
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 18: Average loss: 0.0007, Accuracy: 421/426 (99%)
#
# ------------------ Epoch 19 Iteration 53--------------------------------------
# Accuracy 	 0.958
# Sensitivity 	 0.917
# Specificity 	 1.000
# Area Under ROC 	 0.998
# Val Loss 	 0.10003818049881374
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 19: Average loss: 0.0005, Accuracy: 423/426 (99%)
#
# ------------------ Epoch 20 Iteration 53--------------------------------------
# Accuracy 	 0.966
# Sensitivity 	 0.933
# Specificity 	 1.000
# Area Under ROC 	 0.998
# Val Loss 	 0.09277271545821957
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 20: Average loss: 0.0003, Accuracy: 424/426 (100%)
#
# ------------------ Epoch 21 Iteration 53--------------------------------------
# Accuracy 	 0.958
# Sensitivity 	 0.917
# Specificity 	 1.000
# Area Under ROC 	 0.998
# Val Loss 	 0.09561581164210414
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 21: Average loss: 0.0003, Accuracy: 424/426 (100%)
#
# ------------------ Epoch 22 Iteration 53--------------------------------------
# Accuracy 	 0.983
# Sensitivity 	 0.967
# Specificity 	 1.000
# Area Under ROC 	 0.997
# Val Loss 	 0.0706288458701844
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 22: Average loss: 0.0009, Accuracy: 422/426 (99%)
#
# ------------------ Epoch 23 Iteration 53--------------------------------------
# Accuracy 	 0.958
# Sensitivity 	 0.917
# Specificity 	 1.000
# Area Under ROC 	 0.997
# Val Loss 	 0.11917220506293233
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 23: Average loss: 0.0003, Accuracy: 424/426 (100%)
#
# ------------------ Epoch 24 Iteration 53--------------------------------------
# Accuracy 	 0.958
# Sensitivity 	 0.917
# Specificity 	 1.000
# Area Under ROC 	 0.996
# Val Loss 	 0.1155643614688112
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 24: Average loss: 0.0004, Accuracy: 421/426 (99%)
#
# ------------------ Epoch 25 Iteration 53--------------------------------------
# Accuracy 	 0.983
# Sensitivity 	 0.967
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.08194334773676624
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 25: Average loss: 0.0006, Accuracy: 423/426 (99%)
#
# ------------------ Epoch 26 Iteration 53--------------------------------------
# Accuracy 	 0.941
# Sensitivity 	 0.883
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.16209038310165244
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 26: Average loss: 0.0005, Accuracy: 422/426 (99%)
#
# ------------------ Epoch 27 Iteration 53--------------------------------------
# Accuracy 	 0.975
# Sensitivity 	 0.950
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.0916896924615988
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 27: Average loss: 0.0004, Accuracy: 420/426 (99%)
#
# ------------------ Epoch 28 Iteration 53--------------------------------------
# Accuracy 	 0.958
# Sensitivity 	 0.917
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.11209586232447084
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 28: Average loss: 0.0002, Accuracy: 425/426 (100%)
#
# ------------------ Epoch 29 Iteration 53--------------------------------------
# Accuracy 	 0.966
# Sensitivity 	 0.933
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.11427841455612603
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 29: Average loss: 0.0002, Accuracy: 425/426 (100%)
#
# ------------------ Epoch 30 Iteration 53--------------------------------------
# Accuracy 	 0.983
# Sensitivity 	 0.967
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.07593031482283549
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 30: Average loss: 0.0002, Accuracy: 425/426 (100%)
#
# ------------------ Epoch 31 Iteration 53--------------------------------------
# Accuracy 	 0.949
# Sensitivity 	 0.900
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.14416850308774276
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 31: Average loss: 0.0002, Accuracy: 426/426 (100%)
#
# Updating the learning rate to 0.0001
# ------------------ Epoch 32 Iteration 53--------------------------------------
# Accuracy 	 0.983
# Sensitivity 	 0.967
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.08156918714036389
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 32: Average loss: 0.0002, Accuracy: 423/426 (99%)
#
# ------------------ Epoch 33 Iteration 53--------------------------------------
# Accuracy 	 0.975
# Sensitivity 	 0.950
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.10302369450637343
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 33: Average loss: 0.0004, Accuracy: 422/426 (99%)
#
# ------------------ Epoch 34 Iteration 53--------------------------------------
# Accuracy 	 0.949
# Sensitivity 	 0.900
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.11887609662959828
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 34: Average loss: 0.0002, Accuracy: 424/426 (100%)
#
# ------------------ Epoch 35 Iteration 53--------------------------------------
# Accuracy 	 0.958
# Sensitivity 	 0.917
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.11651709360230597
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 35: Average loss: 0.0003, Accuracy: 422/426 (99%)
#
# ------------------ Epoch 36 Iteration 53--------------------------------------
# Accuracy 	 0.958
# Sensitivity 	 0.917
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.11462496670161879
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 36: Average loss: 0.0002, Accuracy: 425/426 (100%)
#
# ------------------ Epoch 37 Iteration 53--------------------------------------
# Accuracy 	 0.983
# Sensitivity 	 0.967
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.07252501496914192
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 37: Average loss: 0.0003, Accuracy: 422/426 (99%)
#
# ------------------ Epoch 38 Iteration 53--------------------------------------
# Accuracy 	 0.983
# Sensitivity 	 0.967
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.07363845237268833
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 38: Average loss: 0.0002, Accuracy: 425/426 (100%)
#
# ------------------ Epoch 39 Iteration 53--------------------------------------
# Accuracy 	 0.975
# Sensitivity 	 0.950
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.09374038902921408
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 39: Average loss: 0.0001, Accuracy: 426/426 (100%)
#
# ------------------ Epoch 40 Iteration 53--------------------------------------
# Accuracy 	 0.975
# Sensitivity 	 0.950
# Specificity 	 1.000
# Area Under ROC 	 0.998
# Val Loss 	 0.09929263564918074
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 40: Average loss: 0.0002, Accuracy: 425/426 (100%)
#
# ------------------ Epoch 41 Iteration 53--------------------------------------
# Accuracy 	 0.983
# Sensitivity 	 0.967
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.07852725542282618
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 41: Average loss: 0.0002, Accuracy: 424/426 (100%)
#
# ------------------ Epoch 42 Iteration 53--------------------------------------
# Accuracy 	 0.949
# Sensitivity 	 0.900
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.1251750452474577
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 42: Average loss: 0.0002, Accuracy: 424/426 (100%)
#
# ------------------ Epoch 43 Iteration 53--------------------------------------
# Accuracy 	 0.958
# Sensitivity 	 0.917
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.11271055983403737
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 43: Average loss: 0.0003, Accuracy: 424/426 (100%)
#
# ------------------ Epoch 44 Iteration 53--------------------------------------
# Accuracy 	 0.975
# Sensitivity 	 0.950
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.0898984222094441
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 44: Average loss: 0.0002, Accuracy: 425/426 (100%)
#
# ------------------ Epoch 45 Iteration 53--------------------------------------
# Accuracy 	 0.958
# Sensitivity 	 0.917
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.11695643923588553
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 45: Average loss: 0.0001, Accuracy: 424/426 (100%)
#
# ------------------ Epoch 46 Iteration 53--------------------------------------
# Accuracy 	 0.983
# Sensitivity 	 0.967
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.0888754097650235
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 46: Average loss: 0.0004, Accuracy: 422/426 (99%)
#
# ------------------ Epoch 47 Iteration 53--------------------------------------
# Accuracy 	 0.983
# Sensitivity 	 0.967
# Specificity 	 1.000
# Area Under ROC 	 0.999
# Val Loss 	 0.07719550983486746
# ------------------------------------------------------------------------------
#
# Training Performance Epoch 47: Average loss: 0.0001, Accuracy: 426/426 (100%)

# %%
model = torch.load("best_model.pkl" )

metrics_dict = compute_metrics(model, test_loader, plot_roc_curve = True)
print('------------------- Test Performance --------------------------------------')
print("Accuracy \t {:.3f}".format(metrics_dict['Accuracy']))
print("Sensitivity \t {:.3f}".format(metrics_dict['Sensitivity']))
print("Specificity \t {:.3f}".format(metrics_dict['Specificity']))
print("Area Under ROC \t {:.3f}".format(metrics_dict['Roc_score']))
print("--------------------------------------------------------")
# Out:
# ------------------- Test Performance --------------------------------------
# Accuracy 	 0.980
# Sensitivity 	 0.959
# Specificity 	 1.000
# Area Under ROC 	 1.000
# --------------------------------------------------------

# %%
conf_matrix = metrics_dict["Confusion Matrix"]
ax= plt.subplot()
sns.heatmap(conf_matrix, annot=True, ax = ax, cmap = 'Blues'); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['CoViD', 'NonCoViD']); ax.yaxis.set_ticklabels(['CoViD', 'NonCoViD']);
